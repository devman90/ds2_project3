# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(0)

# %%
df = []
for idx in range(1, 13):
    df.append(pd.read_csv('kaggle/input/train{}.csv'.format(idx)))

# %%
# 데이터 와꾸
df[0]
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 0           0.000       0.0           49.7534          23.7184
# 1           0.309       0.0           55.8400          26.6200
# 2           0.618       0.0           55.8400          26.6200
# 3           0.926       0.0           55.8400          26.6200
# 4           1.234       0.0           55.8400          26.6200
# ...           ...       ...               ...              ...
# 295714  90908.545       0.0           62.3000          26.5800
# 295715  90908.853       0.0           62.3000          26.5800
# 295716  90909.162       0.0           62.3000          26.5800
# 295717  90909.469       0.0           62.3000          26.5800
# 295718  90909.778       0.0           62.3000          26.5800
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 0                 233.2737              0.8993     0.2231     0.6365
# ...

# %%
# Row 수 
print('# Rows:', len(df[0]))
print('# Cols:', len(df[0].columns))
# Out:
# # Rows: 295719
# # Cols: 20

# %%
# Column 이름들
df[0].columns
# Out:
# Index(['Time (s)', 'CO (ppm)', 'Humidity (%r.h.)', 'Temperature (C)',
#        'Flow rate (mL/min)', 'Heater voltage (V)', 'R1 (MOhm)', 'R2 (MOhm)',
#        'R3 (MOhm)', 'R4 (MOhm)', 'R5 (MOhm)', 'R6 (MOhm)', 'R7 (MOhm)',
#        'R8 (MOhm)', 'R9 (MOhm)', 'R10 (MOhm)', 'R11 (MOhm)', 'R12 (MOhm)',
#        'R13 (MOhm)', 'R14 (MOhm)'],
#       dtype='object')

# %%
df[0]['Time (s)'].max() / 3600
# 데이터 총 길이 - 25시간?
# Out:
# 25.252716111111113

# %%
df[11]['Time (s)'].max() / 3600
# Out:
# 25.25281388888889

# %%
for col in df[0].columns:
    plt.figure(figsize=(16,4))
    for idx, d in enumerate(df):
        plt.plot(d[col], label=str(idx + 1))
    plt.title(col)
    plt.legend(loc='right')
# Out:
# c:\users\y\.conda\envs\colab\lib\site-packages\IPython\core\events.py:74: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\users\y\.conda\envs\colab\lib\site-packages\IPython\core\pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(16,4))
for idx, d in enumerate(df):
    plt.plot(d['Time (s)'], d['CO (ppm)'], label=str(idx + 1))
plt.title(col)
plt.legend(loc='right')

# %%
plt.figure(figsize=(16,4))
for idx, d in enumerate(df):
    plt.plot(d['CO (ppm)'], label=str(idx + 1))
plt.title(col)
plt.legend(loc='right')

# %%
# Time step
steps = (df[0]['Time (s)'][1:].values - df[0]['Time (s)'][:-1].values)
print('Max:', steps.max())
print('Min:', steps.min())
print('Mean:', steps.mean())
sns.histplot(steps)
# Out:
# Max: 0.39800000000104774
# Min: 0.3019999999960419
# Mean: 0.3074205087279097

# %%
plt.scatter(df[0]['R13 (MOhm)'], df[0]['R14 (MOhm)'])

# %%
np.abs(df[0]['CO (ppm)'] - df[1]['CO (ppm)']).mean()
# Out:
# 0.18459486356068708
